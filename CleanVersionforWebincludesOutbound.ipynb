# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\LIDA7NB\Desktop\Code Latest\sample.xlsx',sheet_name="OUTBOUND Files to External")

pd.set_option('display.max_columns', None)
df
# Out:
# c:\highmarkapps\python3.9.2\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                            Unnamed: 0  \
# 0   Requested Setup Date *Required*  \nNOTE: We ca...
# 1                                 2020-01-01 00:00:00
# 2                                 2020-01-01 00:00:00
# 3                                 2021-08-27 00:00:00
# 4                                 2021-08-27 00:00:00
# 5                                 2021-08-27 00:00:00
# 6                                 2021-08-27 00:00:00
# 7                                 2021-08-27 00:00:00
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# ...

# %%
df2 = df.dropna(subset=['Unnamed: 0'])
df2.drop([1,2],inplace=True)
df3=df2.reset_index().drop(['index'],axis=1)
df3
# Out:
# C:\Users\LIDA7NB\AppData\Local\Temp\81\ipykernel_14652\4066188967.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop([1,2],inplace=True)
#                                           Unnamed: 0  \
# 0  Requested Setup Date *Required*  \nNOTE: We ca...
# 1                                2021-08-27 00:00:00
# 2                                2021-08-27 00:00:00
# 3                                2021-08-27 00:00:00
# 4                                2021-08-27 00:00:00
# 5                                2021-08-27 00:00:00
#
#               Last Updated 07/2021  \
# 0             Scenario\n*Required*
# 1  Secure Transport PUSH to vendor
# 2  Secure Transport PUSH to vendor
# 3  Secure Transport PUSH to vendor
# 4  Secure Transport PUSH to vendor
# 5  Secure Transport PUSH to vendor
#
# ...
